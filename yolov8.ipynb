# %% [markdown]
# <a href="https://colab.research.google.com/github/WsThus07/Detecting-TrackingObject/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# YOLOVv8

# %%
# !nvidia-smi
# Out:
# Sun Jan 14 01:33:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.8/699.8 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8s.pt')  # Load an official Detect model

# Perform tracking with the model
results = model.track(source="video.mp4", show=True, conf=0.24, save= True)  # Tracking with default tracker
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 240MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/521) /content/video.mp4: 640x384 4 persons, 1 sports ball, 104.4ms
# video 1/1 (2/521) /content/video.mp4: 640x384 4 persons, 10.9ms
# video 1/1 (3/521) /content/video.mp4: 640x384 4 persons, 10.9ms
# video 1/1 (4/521) /content/video.mp4: 640x384 4 persons, 10.8ms
# ...

# %%
# prompt: type of results

print(type(results))
# Out:
# <class 'list'>

# %%
results[52]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
